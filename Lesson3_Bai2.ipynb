# %%
import math

x =float(input("Enter x: "))
y =float(input("Enter y: "))
z =float(input("Enter z: "))
F = (x+y+z)/(x*x + y**2 +1)- math.fabs(x-z*math.cos(y))
print(f"F = {F}")
# Out:
# Enter x: 0
# Enter y: 0
# Enter z: 0
# F = 0.0
